# %%
import numpy as np
from src.random_variables.inversion import sample_discrete

values = [1, 2, 3]
probs = [0.2, 0.5, 0.3]

rng = np.random.default_rng(seed=123)  # semilla para reproducibilidad

muestras = sample_discrete(values, probs, size=10_000, rng=rng)
print(muestras[:10])
print("Media aproximada:", muestras.mean())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import numpy as np
# ----> 2 from src.random_variables.inversion import sample_discrete
#       4 values = [1, 2, 3]
#       5 probs = [0.2, 0.5, 0.3]
#
# ModuleNotFoundError: No module named 'src'
